# %% [markdown]
# <a href="https://colab.research.google.com/github/qayyumu/GradioExp/blob/main/SESSION_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Intro to Python <table class="tfo-notebook-buttons" align="right" style="margin-top:0px">
#   <td>
#       <a align='left' target="_blank" href="https://www.python.org/doc/"><img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Flogodownload.org%2Fwp-content%2Fuploads%2F2019%2F10%2Fpython-logo.png&f=1&nofb=1&ipt=92ff8f816b6d8c1bd36d772aae08fc560856e3e4adc2fd99a645398e503ccef0&ipo=images"  width="100" /></a>
#   </td>
#  </table>

# %% [markdown]
# ## Data type 🏛
# Python has the following data types built-in by default, in these categories
# ```
#     Text Type     : str
#     Numeric Types : int, float, complex
#     Sequence Types: list, tuple, range
#     Mapping Type  : dict
#     Set Types     : set, frozenset
#     Boolean Type  : bool
#     Binary Types  : bytes, bytearray, memoryview
# ```

# %%
prompt = 'Enter your name:'
message = str('Invalid option')

number = 3
array_index = int(32)

circle_area = 45.356
temperature = float(30.55)

# %% [markdown]
# ### Get datatype of variable
#   to get data type of a variable pytoh have a built in function named type<br>
#   <code> <b><i>type(obj)</code></i></b><br>
#   obj = object for which data type is to be verified

# %%
print(type(temperature))
# Out:
# <class 'float'>

# %% [markdown]
# ### Get list of member functions
#   <code> <b><i>dir(obj)</code></i></b><br>
#   <i><b>dir<i></b> is a python3's bulitin function whihc iterates over all member functions and prints their names. <br>
#     one simple trick of ide can be used to get immidiate information about object by hovering over it pressing <code> tab</code> or <code> shift + tab </code> or in colab you can also use <code> Ctrl + space </code>

# %%
dir(temperature)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setformat__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %% [markdown]
# ## Conditions and loops

# %% [markdown]
# ### Conditions
#     Equals    : a == b
#     Not Equals: a != b
#     Less than : a < b
#     Greater than: a > b
#     Less than or equal to   : a <= b
#     Greater than or equal to: a >= b
#     and operator: and
#     or operator : or

# %%
a = 1
b = 2
if (a < b):
    print('a is less than b')
    # print(f'{a} is less than {b}')
# else:
#     print(f'{a} is grater than {b}')

#######################################
# exercise 1 uncomment line# 5        #
#######################################

#######################################
# exercise 2 uncomment line# 5~8      #
#######################################
# Out:
# a is less than b

# %%
# if else ladder
a, b, c = (1,2,3)
biggest = -1
if a > b and a > c:
    biggest = a
elif b > c:
    biggest = b
else:
    biggest = c
print(f'{biggest} is the biggest number')
#######################################################
# exercise Change this code to print smallest Number #
#######################################################
# Out:
# 3 is the biggest number

# %%
# short hand notation
_str = f'{a} is {"grater" if a>b else "less"} than {b}'
print(_str)
# Out:
# 1 is less than 2

# %% [markdown]
# ## Lists and dictionaries 📔

# %% [markdown]
# Lists enable you to store a set of items in place. Lists take the form of arrays in other languages like Java.
#
# A list in Python is created using the following syntax:
# <br><code> listname = [item1, item2, item3, ...]</code>

# %%
aiProblmodelems = ['Classification', 'Regression', 'clustering', 'segmentatoin', 'signalprocessing']
print(aiProblmodelems)
# Out:
# ['Classification', 'Regression', 'clustering', 'segmentatoin', 'signalprocessing']

# %%
array = [1, 2, 3]
emptyArray = []
alsoEmptyArray = list()

length_and_area = (45, 300.456)

# length_and_area.index(45)

# %%
# access list item
tartget_users = [
    '@SparkleNinja42',
    '@GigaByteGal',
    '@NeonTiger23',
    '@JazzJunkie101',
    '@PixelPioneer77',
    '@LunarLullaby',
    '@EchoEnigma88',
    '@CryptoComet9',
    '@VortexVoyager',
    '@ZenithZephyr21'

    ]
print(tartget_users[0])

print(tartget_users[-1])

tartget_users.append('@QuantumQuasar18')
print(tartget_users)

tartget_users.insert(2,'@NovaNebula55')
print(tartget_users)

tartget_users.remove('@ZenithZephyr21')
print(tartget_users)
# Out:
# @SparkleNinja42
# @ZenithZephyr21
# ['@SparkleNinja42', '@GigaByteGal', '@NeonTiger23', '@JazzJunkie101', '@PixelPioneer77', '@LunarLullaby', '@EchoEnigma88', '@CryptoComet9', '@VortexVoyager', '@ZenithZephyr21', '@QuantumQuasar18']
# ['@SparkleNinja42', '@GigaByteGal', '@NovaNebula55', '@NeonTiger23', '@JazzJunkie101', '@PixelPioneer77', '@LunarLullaby', '@EchoEnigma88', '@CryptoComet9', '@VortexVoyager', '@ZenithZephyr21', '@QuantumQuasar18']
# ['@SparkleNinja42', '@GigaByteGal', '@NovaNebula55', '@NeonTiger23', '@JazzJunkie101', '@PixelPioneer77', '@LunarLullaby', '@EchoEnigma88', '@CryptoComet9', '@VortexVoyager', '@QuantumQuasar18']

# %% [markdown]
# ### Slicing a list
# To derive a segment, you need to specify the index of the first element and where to stop slicing.
#
# In Python, we use a colon(:) as a slicing operator. Slicing follows the following syntax.<br>
# <code> list_name[Index_start:Index_end] </code>

# %%
tartget_users = [
    '@SparkleNinja42',
    '@GigaByteGal',
    '@NeonTiger23',
    '@JazzJunkie101',
    '@PixelPioneer77',
    '@LunarLullaby',
    '@EchoEnigma88',
    '@CryptoComet9',
    '@VortexVoyager',
    '@ZenithZephyr21'

    ]
print(tartget_users[0:3])
print(tartget_users[:3])
print(tartget_users[3:])

#######################################################
# exercise 1: list items including index 2 and 4      #
# Hint:                                               #
#      last number in range is not included           #
#######################################################
# Out:
# ['@SparkleNinja42', '@GigaByteGal', '@NeonTiger23']
# ['@SparkleNinja42', '@GigaByteGal', '@NeonTiger23']
# ['@JazzJunkie101', '@PixelPioneer77', '@LunarLullaby', '@EchoEnigma88', '@CryptoComet9', '@VortexVoyager', '@ZenithZephyr21']

# %% [markdown]
# # Dictionaries
# Dictionaries are used to store data values in key:value pairs.
# A dictionary is a collection which is ordered*, changeable and do not allow duplicates.
#
#     dict = {
#         "key": "value",
#         "string": "Name",
#         "number": 40,
#         "list " : [item1, item2, ....]
#         "dict " : {'key', 'value'}
#     }

# %%
userDetails =	{
   "userName" : "Jaims",
   "userHandle": "@iamjaims",
   "isActive"   : 0,
   "targetScore": 0.321

}
print(modelOutputLog)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [20], in <cell line: 8>()
#       1 userDetails =	{
#       2    "userName" : "Jaims",
#       3    "userHandle": "@iamjaims",
#    (...)
#       6
#       7 }
# ----> 8 print(modelOutputLog)
#
# NameError: name 'modelOutputLog' is not defined

# %%
#accessing dictionary items
print(userDetails["userName"])
print(userDetails.items())
print(userDetails.keys())
print(userDetails.values())

# %%
# update dictionary items
userDetails.update({"userName": "David"})
print(userDetails)
#delete item from dictionary
del userDetails['targetScore']
print(userDetails)

# %%
#iterate over dictionary
for key, item in userDetails.items():
    print(f'userDetails["{key}"] = {item}')

# %%
#Nested Dictionaries
login_prcess = {
        "login_sequence": [
            {
                "info": "Username field details",
                "type": "tag",
                "value": "input",
                "required_items": [
                    {
                        "idx": 0,
                        "identifier": {
                            "id_type":"attrib",
                            "attrib":"aria-label",
                            "value":"Phone number, username, or email"
                        },
                        "action": "text",
                        "payload": ""
                    },
                    {
                        "idx": 1,
                        "identifier": {
                            "id_type":"attrib",
                            "attrib":"aria-label",
                            "value":"Password"
                        },
                        "action": "text",
                        "payload": ""
                    }
                ]
            },
        ],
        "skip_save_info": [
            {
                "info": "Skip Save button",
                "type": "x_path",
                "value": "//*[contains(text(), 'Not now')]",
                "action": "click",
                "payload": ""
            }
        ],
        "avoid_bot_accusition": [
            {
                "info": "Skip Bot Accusitoin prompt",
                "type": "x_path",
                "value": "//*[contains(text(), 'Dismiss')]",
                "action": "click",
                "payload": ""
            }
        ]
    }
print(login_prcess)

#######################################################
# exercise 1: print tag type for avoid_bot_accusition #
# Hint:                                               #
#      you may need to use multiple []                #
#######################################################
# Out:
# {'login_sequence': [{'info': 'Username field details', 'type': 'tag', 'value': 'input', 'required_items': [{'idx': 0, 'identifier': {'id_type': 'attrib', 'attrib': 'aria-label', 'value': 'Phone number, username, or email'}, 'action': 'text', 'payload': ''}, {'idx': 1, 'identifier': {'id_type': 'attrib', 'attrib': 'aria-label', 'value': 'Password'}, 'action': 'text', 'payload': ''}]}], 'skip_save_info': [{'info': 'Skip Save button', 'type': 'x_path', 'value': "//*[contains(text(), 'Not now')]", 'action': 'click', 'payload': ''}], 'avoid_bot_accusition': [{'info': 'Skip Bot Accusitoin prompt', 'type': 'x_path', 'value': "//*[contains(text(), 'Dismiss')]", 'action': 'click', 'payload': ''}]}

# %% [markdown]
# ### Loops 🔄
# Python have two major loops <br><br>
#     <code> For Loop </code><br>
#         &emsp; for (place holders ) in (range, list, iterator):<br>
#             &emsp;&emsp;&emsp;do action<br>
#
# <code> While Loop </code><br>
#     &emsp; while condition:<br>
#             &emsp;&emsp;&emsp;do action<br>

# %% [markdown]
# ### for loop

# %%
# range is a python's builtin function which returnes a list of numbers
# in the given range it takes 3 arguments which are as following
# arg1: starting_Point  arg2: end_point   arg_3: Step_size

for x in range(2, 30, 3):
  print(x, end=', ')

#######################################################
# exercise 1: change above given loop to only print   #
# even numbers between 4 and 100                      #
# Hint:                                               #
#      start from 4 and increment wiht 2              #
#######################################################

#######################################################
# exercise 2: uncomment line number 22~25 and rerun   #
# Hint:                                               #
#      zip is used toreshape merge multiple iterators into   #
#      one single iteratr wiht valued mapeed on index #
#######################################################

# fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
# prices  = [1,2,3,4,5]
# for fruit, price in zip(fruits, prices):
#     print(f"{fruit} is sold for {price}")
# Out:
# 2, 5, 8, 11, 14, 17, 20, 23, 26, 29,

# %% [markdown]
# ### while Loop

# %%
number = 1
while int(number) > 0:
    number = input("Enter a +ve number or -ve/0 to end ")
# else:
#     print("so it finally end." )

###################################################
# exercise 1: uncomment line number 4&5 and rerun #
# exercise 2: update loop to also exit for number #
# bigger than 20.                                 #
# Hint use 'and' or break statement               #
###################################################

# %% [markdown]
# ### List Comprehention

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []
for x in fruits:
  if "a" in x:
    newlist.append(x)
print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x for x in fruits if "a" in x]
print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %% [markdown]
# ## Functions
# A function is a block of code which only runs when it is called.<br>
# You can pass data, known as parameters, into a function.<br>
# A function may and maynot return data as a result.<br>
#
# <b>Syntax</b><br>
#
#     def functionName(parameters .....):
#         do action
#         return data

# %%
def print_n_time(message, count):
    for i in range(count):
        print(message)

def debug_log(level, debug_msg):
    import time # time is an external module will be discussed later
    if level >5:
        print(f"[ DBG ] {debug_msg}")
    else :
        print(f"[ DBG ] [{time.time()}] {debug_msg}")

debug_log(1,"hello")
debug_log(8,"hello")

########################################
# exercise 1: add your own debug level #
# hint:                                #
# add a new elif statemtn              #
########################################
# Out:
# [ DBG ] [1721403333.8446422] hello
# [ DBG ] hello

# %%
def line(m, x, c):
    return m*x + c

def predict_next(weights, _input):
    pred = line(weights, _input, 0)
    return _input, pred

_input, prediction = predict_next(12,4)
print(f'Input: {_input} Prediction: {prediction}')

#######################################
# exercise 1: modify predict_next to  #
# take extra argument named as biase  #
# and add it to line function's       #
# input(c)                            #
# hint:                               #
# functio signature should look like  #
# predict_next(weight, _input, biase) #
#######################################
# Out:
# Input: 4 Prediction: 48

# %%
#######################################
# exercise 1: write a function named  #
# relu with following functinality    #
# return 0 if number is -ve or same   #
# number is returned                  #
# hint:                               #
# Use IF-else and return              #
# functio signature                   #
# def relu(input)                     #
#######################################


# def sigmoid(x):
#     z = (1./(1. + np.exp(-x)))
#     return z
